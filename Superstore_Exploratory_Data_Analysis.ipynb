# %% [markdown]
# ## **Superstore Exploratory Data Analysis**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing Superstore Dataset.
df = pd.read_csv("Sample - Superstore.csv", encoding = "latin-1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Including all columns.
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df[["Sales", "Quantity", "Discount", "Profit"]].describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
import ml_stats

# %%
for col_name in ["Sales", "Quantity", "Discount", "Profit"]:
    print(col_name)
    stats_obj = ml_stats.ml_stats(df[col_name])
    stats_obj.stats_process()
    print("_"*100)
# Out:
# Sales
# Total: 2297200.8603
# Length: 9994
# Maximum Value: 22638.48
# Minimum value: 0.444
# Range of Data: 22638.036
# Mean: 229.85800083049833
# Median: 54.489999999999995
# Mode: 12.96
# Quartile 1: 17.28
# Quartile 3: 209.94
# IQR: 192.66
# Lower Whisker: -271.71000000000004
# Upper Whisker: 498.93
# Total Outliers Count: 1167
# Variance 388395.58854248666
# Standard Deviation 623.2139187650471
# 1 Standard Deviation Range: -393.36 to 853.07 --> 93.97% of data
# 2 Standard Deviation Range: -1016.57 to 1476.29 --> 97.53% of data
# 3 Standard Deviation Range: -1639.78 to 2099.50 --> 98.73% of data
# Skewness: 12.968858439383038
# Kurtosis: 305.0967612162073
# Likely does NOT follows Normal Distribution
# 95% Confidence Interval: 217.64 to 242.08
# 97% Confidence Interval: 216.33 to 243.39
# 99% Confidence Interval: 213.80 to 245.92
# Detected Continuous Data
# ____________________________________________________________________________________________________
# Quantity
# ...

# %% [markdown]
# ## Inference from above analysis: -
#
# 1) Sales: -
#     * Range being so high(22638) means we the store has wide variety of products. They sell cheap products as well as expensive products.
#     * Median being 54 and Mean 229 means there are OUTLIERS in our data. The difference is too much. Meaing people usually buy cheap products but some customers buy expensive products thus mean is very high.
#     * Mode 12.96 means most of our customers buy 12.96 dollars product.
#     * Q1 and Q3 represents majority of our customers buy products in the range of 17 to 209.
#     * Q3 being 209 and mean(229) being greater than Q3 again proves we have too much OUTLIERS.
#     * Total count of OUTLIERS is 1167 meaning out of 10000 people approx 1200 people are OUTLIERS that is 12% people. So if everyday 100 customers are coming, 88% will buy average products and 12% will buy expensive products.
#     * Std being 623 and mean 229 meaning data points are 623 away from the mean. That means each customer has different buying habits. Majority of the customers does not show same buying habits.
#     * 1 Standard Deviation range has 93.97% of data, which means majority of the business revolves around 1st Standard Deviation. Therefore if I analyse only 1st Standard Deviation, I'll understand 93.97% of the customer base.
#     * Skewness being 12 meaning we have POSITIVE OUTLIERS. Our data is Right Skewed.
#     * Kurtosis being 305 means the data has a sharp peak around the mean. Which means majority of the customers buy products around the mean.
#     * 95% confidence interval is between 217 to 242 which means we are 95% confidence that our best guess at truth lies between 217 to 242. The mean(229) is the average of this sample of 10000 customers but the superstore serves more than 10k customers. Therefore we use inferential statistics to predict for the population and we use confidence interval to give the best range.

# %%
df[df["Sales"] == df["Sales"].max()]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  3/18/2014  3/23/2014  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville
#
#         State  Postal Code Region       Product ID    Category Sub-Category  \
# 2697  Florida        32216  South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
#
#       Discount     Profit
# 2697       0.5 -1811.0784

# %% [markdown]
# The profit seems to be in negative. Therefore the most expensive sales made loss for the store.

# %%
df[df["Customer ID"] == "SM-20320"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2266    2267  CA-2017-149146  10/12/2017  10/12/2017        Same Day
# 2573    2574  CA-2017-145128    7/9/2017   7/14/2017  Standard Class
# 2696    2697  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 2697    2698  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 2698    2699  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 2699    2700  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 2700    2701  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 2701    2702  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 2702    2703  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 7853    7854  CA-2015-144890  12/25/2015  12/29/2015  Standard Class
# 9187    9188  US-2015-130512   8/21/2015   8/25/2015  Standard Class
# 9188    9189  US-2015-130512   8/21/2015   8/25/2015  Standard Class
# 9189    9190  US-2015-130512   8/21/2015   8/25/2015  Standard Class
# ...

# %%
sean_miller = df[df["Customer ID"] == "SM-20320"]

# %%
sean_miller[["Sales", "Profit", "Quantity", "Discount"]].describe()
# Out:
#               Sales       Profit   Quantity   Discount
# count     15.000000    15.000000  15.000000  15.000000
# mean    1669.536667  -132.049287   3.333333   0.246667
# std     5807.087126   467.115828   1.447494   0.184649
# min        3.488000 -1811.078400   2.000000   0.000000
# 25%       14.448000    -8.561800   2.000000   0.200000
# 50%       30.768000     3.802400   3.000000   0.200000
# 75%      324.401000     7.779100   4.000000   0.200000
# max    22638.480000    31.587000   6.000000   0.700000

# %%
sean_miller["Discount"].value_counts()
# Out:
# Discount
# 0.2    10
# 0.0     2
# 0.5     2
# 0.7     1
# Name: count, dtype: int64

# %%
sean_miller["Discount"].value_counts().plot(kind = "bar");

# %%
df["Discount"].value_counts().sort_index().plot(kind = "bar");

# %%
print(f"{round((df["Discount"] == 0.0).sum()/len(df) * 100)}% of people get NO discount")
# Out:
# 48% of people get NO discount

# %%
print(f"{100 - round((df["Discount"] == 0.0).sum()/len(df) * 100)}% of people get discount")
# Out:
# 52% of people get discount

# %%
plt.figure(figsize = (10,6))
sns.lmplot(data = df, x = "Discount", y = "Sales")
plt.title("Regression Plot Discount vs Sales")
plt.show()

# %%
import itertools
l1 = ["Sales", "Profit", "Quantity", "Discount"]
for i, j in itertools.combinations(l1, 2):
    print(i, j)
# Out:
# Sales Profit
# Sales Quantity
# Sales Discount
# Profit Quantity
# Profit Discount
# Quantity Discount

# %%
import itertools
l1 = ["Sales", "Discount", "Quantity","Profit"]
for i, j in itertools.combinations(l1, 2):
    print(i, j)
    plt.figure(figsize = (10,6))
    plt.title(f"Regression Plot between {i} vs {j}")
    sns.lmplot(data = df, x = i, y = j)
    plt.show()
# Out:
# Sales Discount
# Sales Quantity
# Sales Profit
# Discount Quantity
# Discount Profit
# Quantity Profit

# %%
df["Profit"][df["Discount"] <= 0.2].mean()
# Out:
# 49.0376790722009

# %%
df["Profit"][df["Discount"] > 0.2].mean()
# Out:
# -97.1830983488873

# %%
df["Profit"].mean()
# Out:
# 28.65689630778467

# %%
plt.title("Correlation Heatmap")
sns.heatmap(df[["Sales", "Profit", "Discount", "Quantity"]].corr(), annot = True, cmap = "coolwarm", vmin = -1);
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df[["Ship Mode"]]
# Out:
#            Ship Mode
# 0       Second Class
# 1       Second Class
# 2       Second Class
# 3     Standard Class
# 4     Standard Class
# ...              ...
# 9989    Second Class
# 9990  Standard Class
# 9991  Standard Class
# 9992  Standard Class
# 9993    Second Class
#
# [9994 rows x 1 columns]

# %%
# Top 10 values in the categorical columns.
for col_name in ["Ship Mode", "Segment", "State", "Region", "Category", "Sub-Category", "Product Name"]:
    plt.figure(figsize = (7,5))
    plt.title(col_name)
    df.groupby(col_name)["Profit"].sum().sort_values(ascending = False).head(10).plot(kind = "bar")
    plt.show()

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df.groupby(["Ship Mode"])["Profit"].sum().sort_values(ascending = False)/sum(df["Profit"])*100
# Out:
# Ship Mode
# Standard Class    57.294167
# Second Class      20.058391
# First Class       17.098586
# Same Day           5.548856
# Name: Profit, dtype: float64

# %%
df.groupby(["Ship Mode"])["Profit"].mean().sort_values(ascending = False)
# Out:
# Ship Mode
# First Class       31.839948
# Second Class      29.535545
# Same Day          29.266591
# Standard Class    27.494770
# Name: Profit, dtype: float64

# %%
df.groupby(["Ship Mode"])["Profit"].median().sort_values(ascending = False)
# Out:
# Ship Mode
# Second Class      9.4284
# First Class       8.7789
# Standard Class    8.3010
# Same Day          8.0270
# Name: Profit, dtype: float64

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df["Category"].value_counts().plot(kind = "bar");

# %%
df["Category"].value_counts()/len(df)
# Out:
# Category
# Office Supplies    0.602962
# Furniture          0.212227
# Technology         0.184811
# Name: count, dtype: float64

# %%
df.groupby(["Category"])["Profit"].sum().sort_values(ascending = False)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
df.groupby(["Category"])["Profit"].median().sort_values(ascending = False)
# Out:
# Category
# Technology         25.0182
# Furniture           7.7748
# Office Supplies     6.8824
# Name: Profit, dtype: float64

# %%
df.groupby(["Category"])["Profit"].mean().sort_values(ascending = False)
# Out:
# Category
# Technology         78.752002
# Office Supplies    20.327050
# Furniture           8.699327
# Name: Profit, dtype: float64

# %%
for i in df["Category"].unique():
    plt.figure(figsize = (7,5))
    plt.title(f"{i} Violin Plot")
    sns.violinplot(x = df["Profit"][df["Category"] == i])
    plt.show()

# %%
furniture_df = df[df["Category"] == "Furniture"]

# %%
furniture_df[furniture_df["Profit"] < -1000]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 27        28  US-2015-150630  9/17/2015  9/21/2015  Standard Class
# 5320    5321  US-2017-162558  10/2/2017  10/5/2017     First Class
# 9639    9640  CA-2015-116638  1/28/2015  1/31/2015    Second Class
#
#      Customer ID    Customer Name      Segment        Country          City  \
# 27      TB-21520  Tracy Blumstein     Consumer  United States  Philadelphia
# 5320    Dp-13240      Dean percer  Home Office  United States     Knoxville
# 9639    JH-15985      Joseph Holt     Consumer  United States       Concord
#
#                State  Postal Code Region       Product ID   Category  \
# 27      Pennsylvania        19140   East  FUR-BO-10004834  Furniture
# 5320       Tennessee        37918  South  FUR-TA-10000198  Furniture
# 9639  North Carolina        28027  South  FUR-TA-10000198  Furniture
#
#      Sub-Category                                       Product Name  \
# ...

# %%
for i in furniture_df["Product ID"][furniture_df["Profit"] < -1000]:
    print(i, df["Profit"][df["Product ID"] == i].mean())
# Out:
# FUR-BO-10004834 -133.90896000000006
# FUR-TA-10000198 -575.22312
# FUR-TA-10000198 -575.22312

# %%
df["Profit"].value_counts().sort_index(ascending = False).head()/len(df)*100
# Out:
# Profit
# 8399.9760    0.010006
# 6719.9808    0.010006
# 5039.9856    0.010006
# 4946.3700    0.010006
# 4630.4755    0.010006
# Name: count, dtype: float64

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
plt.figure(figsize = (7,5))
wc = WordCloud(max_words = 100, background_color="black").generate(" ".join(df["Product Name"]))
plt.title("Product Name WordCloud")
plt.imshow(wc)
plt.show()

# %% [markdown]
# ## Insights
#
# 1) Just because people are purchasing expensive product doesn't mean superstore is earning more profit.
# 2) Just because people are purchasing MORE product doesn't mean superstore is earning more profit.
# 3) Superstore earns more profit if clever discounts are given.
# 4) Negative correlation of Profit vs Discount (-0.22) is the biggest concern of sales management.
# 5) Expected Sales vs Profit correlation was high instead it is weak positive (0.48).
